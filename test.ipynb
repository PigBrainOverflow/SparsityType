# %%
import numpy as np
import scipy.sparse as sp

a = np.array([1, 2, 3])
b = sp.csr_matrix([1, 0, 0])

print(a + b)

# %%
import spring as spr

a = spr.NDArray.from_obj([1, 2, 3])
b = spr.NDArray.from_obj([[1, 0, 0], [0, 1, 0], [0, 0, 1]])

print(a + b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 6
#       3 a = spr.NDArray.from_obj([1, 2, 3])
#       4 b = spr.NDArray.from_obj([[1, 0, 0], [0, 1, 0], [0, 0, 1]])
# ----> 6 print(a + b)
#
# File ~/SparsityType/spring/core.py:136, in NDArray.__add__(self, other)
#     134 def __add__(self, other: Any) -> NDArray:
#     135     if isinstance(other, NDArray):
# --> 136         return self._add_array(other)
#     137     return self._add_scalar(other)
#
# File ~/SparsityType/spring/core.py:123, in NDArray._add_array(self, other)
#     121     raise ValueError("Data is not initialized.")
#     122 if self.shape != other.shape:
# --> 123     raise ValueError("Shapes do not match for addition.")
#     124 res_data = cast(np.ndarray, self._data) + cast(np.ndarray, other._data) # type: ignore
#     125 if isinstance(res_data, np.ndarray):
#
# ...
